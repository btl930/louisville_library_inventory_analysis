# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
oss_demo = pd.read_csv('../data/RCS_Households_Demographics.csv')

# %%
oss_demo.shape
# Out:
# (50553, 8)

# %%
oss_demo.head()
# Out:
#   Household_Index              Date_Added         Housing_Type  \
# 0            6096  2018/09/11 23:41:00+00                  Own
# 1           10233  2018/09/24 21:28:00+00  Rent/Non-Subsidized
# 2           10234  2018/09/24 21:28:00+00                  Own
# 3           10238  2018/09/24 21:30:00+00                  Own
# 4           10239  2018/09/24 21:30:00+00      Rent/Subsidized
#
#          Household_Type  Household_Size Annual_Income  ZIP_Code  ObjectId
# 0         Single Person               1   $13,152.00    40214.0         1
# 1  Single Parent Female               2        $0.00    40210.0         2
# 2  Single Parent Female               3   $12,456.00    40211.0         3
# 3  Single Parent Female               1   $10,356.00    40299.0         4
# 4  Single Parent Female               2   $20,672.52    40216.0         5

# %%
oss_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50553 entries, 0 to 50552
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Household_Index  50553 non-null  object
#  1   Date_Added       47525 non-null  object
#  2   Housing_Type     49409 non-null  object
#  3   Household_Type   50553 non-null  object
#  4   Household_Size   50553 non-null  int64
#  5   Annual_Income    47677 non-null  object
#  6   ZIP_Code         49613 non-null  float64
#  7   ObjectId         50553 non-null  int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 3.1+ MB

# %%
oss_demo.columns
# Out:
# Index(['Household_Index', 'Date_Added', 'Housing_Type', 'Household_Type',
#        'Household_Size', 'Annual_Income', 'ZIP_Code', 'ObjectId'],
#       dtype='object')

# %%
oss_demo = oss_demo.drop(['Household_Index'], axis=1)

# %%
oss_demo = oss_demo.drop(['ObjectId'], axis=1)

# %%
oss_demo.columns
# Out:
# Index(['Date_Added', 'Housing_Type', 'Household_Type', 'Household_Size',
#        'Annual_Income', 'ZIP_Code'],
#       dtype='object')

# %%
oss_demo.isna().sum()
# Out:
# Date_Added        3028
# Housing_Type      1144
# Household_Type       0
# Household_Size       0
# Annual_Income     2876
# ZIP_Code           940
# dtype: int64

# %%
oss_demo = oss_demo.dropna(subset=['ZIP_Code'])

# %%
oss_demo.isna().sum()
# Out:
# Date_Added        3028
# Housing_Type       353
# Household_Type       0
# Household_Size       0
# Annual_Income     2101
# ZIP_Code             0
# dtype: int64

# %%
duplicated_mask = oss_demo.duplicated(keep=False)
duplicated_rows = oss_demo[duplicated_mask]
duplicated_rows
# Out:
#                    Date_Added         Housing_Type     Household_Type  \
# 5568   2018/11/07 00:57:00+00      Rent/Subsidized      Single Person
# 5570   2018/11/07 00:57:00+00      Rent/Subsidized      Single Person
# 11498  2019/01/23 04:13:00+00  Rent/Non-Subsidized      Single Person
# 11502  2019/01/23 04:13:00+00  Rent/Non-Subsidized      Single Person
# 37070  2021/06/04 18:31:00+00  Rent/Non-Subsidized      Single Person
# ...                       ...                  ...                ...
# 50498                     NaN                  NaN        Lives alone
# 50537                     NaN                  NaN  Lives with spouse
# 50538                     NaN                  NaN  Lives with spouse
# 50543                     NaN                  NaN        Lives alone
# 50544                     NaN                  NaN        Lives alone
#
#        Household_Size  Annual_Income  ZIP_Code
# 5568                1            0.0   40203.0
# 5570                1            0.0   40203.0
# 11498               1            0.0   40218.0
# 11502               1            0.0   40218.0
# 37070               1            0.0   40214.0
# ...               ...            ...       ...
# 50498               1            NaN   40228.0
# 50537               2            NaN   40245.0
# 50538               2            NaN   40245.0
# 50543               1            NaN   40218.0
# 50544               1            NaN   40218.0
#
# [1273 rows x 6 columns]

# %%
oss_demo['Date_Added'] = pd.to_datetime(oss_demo['Date_Added'])

# %%
oss_demo['Annual_Income'] = oss_demo['Annual_Income'].replace(r'[\$,]', '', regex=True).astype(float)

# %%
oss_demo['ZIP_Code'] = oss_demo['ZIP_Code'].astype(int)

# %%
oss_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49613 entries, 0 to 50552
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date_Added      46585 non-null  datetime64[ns, UTC]
#  1   Housing_Type    49260 non-null  object
#  2   Household_Type  49613 non-null  object
#  3   Household_Size  49613 non-null  int64
#  4   Annual_Income   47512 non-null  float64
#  5   ZIP_Code        49613 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(1), int64(2), object(2)
# memory usage: 2.6+ MB
